# %%
import os
import torch
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scienceplots

plt.style.use(['science', 'bright'])
plt.rcParams['figure.dpi'] = 300

# %%
base_spectra01 = torch.load(os.path.join("..","data","simulations","test_1.pt"), weights_only=True)
base_spectra02 = torch.load(os.path.join("..","data","simulations","test_2.pt"), weights_only=True)
base_spectra03 = torch.load(os.path.join("..","data","simulations","test_3.pt"), weights_only=True)
base_spectra04 = torch.load(os.path.join("..","data","simulations","test_4.pt"), weights_only=True)
base_spectra05 = torch.load(os.path.join("..","data","simulations","test_5.pt"), weights_only=True)
base_spectra06 = torch.load(os.path.join("..","data","simulations","test_6.pt"), weights_only=True)
base_spectra07 = torch.load(os.path.join("..","data","simulations","test_7.pt"), weights_only=True)
base_spectra08 = torch.load(os.path.join("..","data","simulations","test_8.pt"), weights_only=True)
base_spectra09 = torch.load(os.path.join("..","data","simulations","test_9.pt"), weights_only=True)
base_spectra10 = torch.load(os.path.join("..","data","simulations","test_10.pt"), weights_only=True)

# %%
for i in range(3):  
    plt.plot(base_spectra01["x"][:][i], label=f'sample {i+1} (1)')
    plt.plot(base_spectra02["x"][:][i], label=f'sample {i+1} (2)')


plt.legend()
plt.show()

# %%
base_spectra01_cov = torch.load(os.path.join("..","data","simulations","test_1_cov_unbinned.pt"), weights_only=True)
base_spectra02_cov = torch.load(os.path.join("..","data","simulations","test_2_cov_unbinned.pt"), weights_only=True)
base_spectra03_cov = torch.load(os.path.join("..","data","simulations","test_3_cov_unbinned.pt"), weights_only=True)
base_spectra04_cov = torch.load(os.path.join("..","data","simulations","test_4_cov_unbinned.pt"), weights_only=True)
base_spectra05_cov = torch.load(os.path.join("..","data","simulations","test_5_cov_unbinned.pt"), weights_only=True)
base_spectra06_cov = torch.load(os.path.join("..","data","simulations","test_6_cov_unbinned.pt"), weights_only=True)
base_spectra07_cov = torch.load(os.path.join("..","data","simulations","test_7_cov_unbinned.pt"), weights_only=True)
base_spectra08_cov = torch.load(os.path.join("..","data","simulations","test_8_cov_unbinned.pt"), weights_only=True)
base_spectra09_cov = torch.load(os.path.join("..","data","simulations","test_9_cov_unbinned.pt"), weights_only=True)
base_spectra10_cov = torch.load(os.path.join("..","data","simulations","test_10_cov_unbinned.pt"), weights_only=True)

# %%
for i in range(5):  
    plt.plot(base_spectra01_cov["x"][:][i], label=f'sample {i+1} (1)')
    plt.plot(base_spectra02_cov["x"][:][i], label=f'sample {i+1} (2)')


plt.legend()
plt.show()

# %%
base_spectra = torch.load(os.path.join("..","data","simulations","01_TT_high_ell_unbinned_noise_planck_50000.pt"), weights_only=True)
for i in range(10):  
    plt.plot(base_spectra["x"][:][i], label=f'sample {i+1} (1)')


plt.legend()
plt.show()

# %%
mean_Cl_1 = np.mean(base_spectra01_cov["x"][:].numpy(), axis=0)
std_Cl_1 =np.std(base_spectra01_cov["x"][:].numpy(), axis=0)

mean_Cl_2 = np.mean(base_spectra02_cov["x"][:].numpy(), axis=0)
std_Cl_2 =np.std(base_spectra02_cov["x"][:].numpy(), axis=0)


mean_Cl_3 = np.mean(base_spectra["x"][:].numpy(), axis=0)
std_Cl_3 =np.std(base_spectra["x"][:].numpy(), axis=0)


plt.figure(figsize=(10, 6))
plt.fill_between(range(len(mean_Cl_1)), mean_Cl_1 - std_Cl_1, mean_Cl_1 + std_Cl_1, alpha=0.3, label='50k test1')
plt.xlabel('Multipolo $\ell$')
plt.ylabel('$C_\ell^{TT}$ [$\mu K^2$]')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.fill_between(range(len(mean_Cl_2)), mean_Cl_2 - std_Cl_2, mean_Cl_2 + std_Cl_2, alpha=0.3, label='50k test2')
plt.xlabel('Multipolo $\ell$')
plt.ylabel('$C_\ell^{TT}$ [$\mu K^2$]')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.fill_between(range(len(mean_Cl_3)), mean_Cl_3 - std_Cl_3, mean_Cl_3 + std_Cl_3, alpha=0.3, label='50k old')
plt.xlabel('Multipolo $\ell$')
plt.ylabel('$C_\ell^{TT}$ [$\mu K^2$]')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.fill_between(range(len(mean_Cl_1)), mean_Cl_1 - std_Cl_1, mean_Cl_1 + std_Cl_1, alpha=0.3, label='50k test1')
plt.fill_between(range(len(mean_Cl_2)), mean_Cl_2 - std_Cl_2, mean_Cl_2 + std_Cl_2, alpha=0.3, label='50k test2')
plt.fill_between(range(len(mean_Cl_3)), mean_Cl_3 - std_Cl_3, mean_Cl_3 + std_Cl_3, alpha=0.3, label='50k old')
plt.xlabel('Multipolo $\ell$')
plt.ylabel('$C_\ell^{TT}$ [$\mu K^2$]')
plt.legend()
plt.show()
